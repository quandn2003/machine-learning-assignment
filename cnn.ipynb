# %%
import tensorflow as tf
import pandas as pd
import numpy as np
from string import digits
from collections import Counter
from pyvi import ViTokenizer
from gensim.models.word2vec import Word2Vec
from tensorflow.keras.utils import to_categorical

# %%
data_train = pd.read_csv("vlsp_sentiment_train.csv", sep='\t')
data_train.columns =['Class', 'Data']
data_test = pd.read_csv("vlsp_sentiment_test.csv", sep='\t')
data_test.columns =['Class', 'Data']

# %%
data_train.head()
# Out:
#    Class                                               Data
# 0     -1  Mình đã dùng anywhere thế hệ đầu, quả là đầy t...
# 1     -1  Quan tâm nhất là độ trễ có cao không, dùng thi...
# 2     -1  dag xài con cùi bắp 98k....pin trâu, mỗi tội đ...
# 3     -1  logitech chắc hàng phải tiền triệu trở lên dùn...
# 4     -1  Đang xài con m175 cùi mía , nhà xài nhiều chuộ...

# %%
data_train = data_train.sample(frac=1, random_state=42)

# %%
data_train.head()
# Out:
#       Class                                               Data
# 4039      0  tuy có sự sáng tạo , nhưng cần phải có phong c...
# 3815      0                                   khoảng 3-4s j đó
# 848      -1               Chiều dài 45cm :( bỏ vào túi kiểu gì
# 4863      0     không , không nên mua . mua samsung ngon hơn .
# 79       -1  thế thì quất thôi, chứ con miband 1s của e bên...

# %%
labels = data_train.iloc[:, 0].values
reviews = data_train.iloc[:, 1].values

# %%
encoded_labels = []

for label in labels:
    if label == -1:
        encoded_labels.append([1,0,0])
    elif label == 0:
        encoded_labels.append([0,1,0])
    else:
        encoded_labels.append([0,0,1])

encoded_labels = np.array(encoded_labels)

# %%
for i in range(5):
    print(encoded_labels[i])
# Out:
# [0 1 0]
# [0 1 0]
# [1 0 0]
# [0 1 0]
# [1 0 0]

# %%
reviews_processed = []
unlabeled_processed = []
for review in reviews:
    review_cool_one = ''.join([char for char in review if char not in digits])
    reviews_processed.append(review_cool_one)

# %%
#Use PyVi for Vietnamese word tokenizer
word_reviews = []
all_words = []
for review in reviews_processed:
    review = ViTokenizer.tokenize(review.lower())
    word_reviews.append(review.split())

# %%
word_reviews[0]
# Out:
# ['tuy',
#  'có',
#  'sự',
#  'sáng_tạo',
#  ',',
#  'nhưng',
#  'cần',
#  'phải',
#  'có',
#  'phong_cách',
#  'riêng',
#  ',',
#  'đừng',
#  'chạy',
#  'theo',
#  'iphone',
#  ',',
#  'samsung',
#  'rất',
#  'cố_gắng',
#  ',',
#  'biết',
#  'nắm_bắt',
#  'nhu_cầu',
#  'khách_hàng',
#  '(',
#  's',
#  's',
#  'edge',
#  'người',
#  'châu',
#  'á',
#  'rất',
#  'chuộng',
#  ',',
#  'nhưng',
#  'ko',
#  'thấy',
#  'phát_triển',
#  'nữa',
#  ')',
#  's',
#  'là',
#  'sự',
#  'hoàn_thiện',
#  'của',
#  's',
#  ',',
#  'nhưng',
#  'sfan',
#  'thì',
#  'luôn',
#  'gato',
#  ',',
#  'vì',
#  'các',
#  'bạn',
#  'ấy',
#  'thấy',
#  'iphone',
#  'quá',
#  'đắt',
#  'và',
#  'các',
#  'bạn',
#  'ấy',
#  'chuẩn_bị',
#  'lên_tiếng',
#  '.']

# %%
EMBEDDING_DIM = 400 # how big is each word vector
MAX_VOCAB_SIZE = 10000 # how many unique words to use (i.e num rows in embedding vector)
MAX_SEQUENCE_LENGTH = 300 # max number of words in a comment to use

# %%
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences
from tensorflow.keras.utils import to_categorical

# %%
tokenizer = Tokenizer(num_words=MAX_VOCAB_SIZE, lower=True, char_level=False)
tokenizer.fit_on_texts(word_reviews)
sequences_train = tokenizer.texts_to_sequences(word_reviews)
word_index = tokenizer.word_index

# %%
# word_index[1]

# %%
data = pad_sequences(sequences_train, maxlen=MAX_SEQUENCE_LENGTH)
labels = encoded_labels

# %%
data
# Out:
# array([[   0,    0,    0, ...,  950, 2022,    1],
#        [   0,    0,    0, ...,   60,  309,   62],
#        [   0,    0,    0, ...,  726,  310,   43],
#        ...,
#        [   0,    0,    0, ...,   11,  434, 1036],
#        [   0,    0,    0, ..., 4142,    6,  158],
#        [   0,    0,    0, ...,   33,   33,    1]])

# %%
print('Shape of X train and X validation tensor:',data.shape)
print('Shape of label train and validation tensor:', labels.shape)
# Out:
# Shape of X train and X validation tensor: (5100, 300)
# Shape of label train and validation tensor: (5100, 3)

# %%
import gensim
from gensim.models import Word2Vec
from gensim.utils import simple_preprocess

from gensim.models.keyedvectors import KeyedVectors

word_vectors = KeyedVectors.load_word2vec_format('vi-model-CBOW.bin', binary=True)


vocabulary_size=min(len(word_index)+1,MAX_VOCAB_SIZE)
embedding_matrix = np.zeros((vocabulary_size, EMBEDDING_DIM))
for word, i in word_index.items():
    if i>=MAX_VOCAB_SIZE:
        continue
    try:
        embedding_vector = word_vectors[word]
        embedding_matrix[i] = embedding_vector
    except KeyError:
        embedding_matrix[i]=np.random.normal(0,np.sqrt(0.25),EMBEDDING_DIM)

del(word_vectors)

from keras.layers import Embedding
embedding_layer = Embedding(vocabulary_size,
                            EMBEDDING_DIM,
                            weights=[embedding_matrix],
                            trainable=True)

# %%
from tensorflow.keras.layers import Dense, Input, GlobalMaxPooling1D
from tensorflow.keras.layers import Conv1D, MaxPooling1D, Embedding, BatchNormalization, AveragePooling1D
from tensorflow.keras.models import Model, load_model
from tensorflow.keras.layers import Input, Dense, Embedding, Dropout,concatenate
from tensorflow.keras.layers import Reshape, Flatten
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint
from tensorflow.keras.optimizers import Adam, SGD
from tensorflow.keras.models import Model
from tensorflow.keras import regularizers

# %%
sequence_length = data.shape[1]
filter_sizes = [3,4,5]
num_filters = 100
drop = 0.5

inputs = Input(shape=(sequence_length,))
embedding = embedding_layer(inputs)

conv_0 = Conv1D(num_filters, filter_sizes[0], activation='relu', kernel_regularizer=regularizers.l2(0.01))(embedding)
maxpool_0 = GlobalMaxPooling1D()(conv_0)

conv_1 = Conv1D(num_filters, filter_sizes[1], activation='relu', kernel_regularizer=regularizers.l2(0.01))(embedding)
maxpool_1 = GlobalMaxPooling1D()(conv_1)

conv_2 = Conv1D(num_filters, filter_sizes[2], activation='relu', kernel_regularizer=regularizers.l2(0.01))(embedding)
maxpool_2 = GlobalMaxPooling1D()(conv_2)

merged_tensor = concatenate([maxpool_0, maxpool_1, maxpool_2], axis=1)
flatten = Flatten()(merged_tensor)
dropout1 = Dropout(drop)(flatten)
output = Dense(units=3, activation='softmax', kernel_regularizer=regularizers.l2(0.01))(dropout1)

model = Model(inputs, output)
print(model)

adam = Adam(learning_rate=0.001, beta_1=0.9, beta_2=0.999, epsilon=1e-08)
model.compile(loss='categorical_crossentropy', optimizer=adam, metrics=['accuracy'])
model.summary()

early_stopping = EarlyStopping(monitor='val_loss', min_delta=0.01, patience=10, verbose=1)
# Out:
# <keras.src.engine.functional.Functional object at 0x000001CA970BBB10>
# Model: "model_3"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_4 (InputLayer)        [(None, 300)]                0         []
#
#  embedding_3 (Embedding)     (None, 300, 400)             3167600   ['input_4[0][0]']
#
#  conv1d_9 (Conv1D)           (None, 298, 100)             120100    ['embedding_3[0][0]']
#
#  conv1d_10 (Conv1D)          (None, 297, 100)             160100    ['embedding_3[0][0]']
#
#  conv1d_11 (Conv1D)          (None, 296, 100)             200100    ['embedding_3[0][0]']
#
#  global_max_pooling1d (Glob  (None, 100)                  0         ['conv1d_9[0][0]']
#  alMaxPooling1D)
#
#  global_max_pooling1d_1 (Gl  (None, 100)                  0         ['conv1d_10[0][0]']
#  obalMaxPooling1D)
#
#  global_max_pooling1d_2 (Gl  (None, 100)                  0         ['conv1d_11[0][0]']
#  obalMaxPooling1D)
#
#  concatenate_3 (Concatenate  (None, 300)                  0         ['global_max_pooling1d[0][0]',
#  )                                                                   'global_max_pooling1d_1[0][0]
#                                                                     ',
#                                                                      'global_max_pooling1d_2[0][0]
#                                                                     ']
#
#  flatten_3 (Flatten)         (None, 300)                  0         ['concatenate_3[0][0]']
#
#  dropout_3 (Dropout)         (None, 300)                  0         ['flatten_3[0][0]']
#
#  dense_3 (Dense)             (None, 3)                    903       ['dropout_3[0][0]']
#
# ==================================================================================================
# Total params: 3648803 (13.92 MB)
# Trainable params: 3648803 (13.92 MB)
# Non-trainable params: 0 (0.00 Byte)
# __________________________________________________________________________________________________

# %%
checkpoint = ModelCheckpoint('cnn.keras',
                             monitor='val_accuracy',
                             save_best_only=True, mode='max')
callbacks_list = [checkpoint, early_stopping]

model.fit(data, labels, validation_split=0.2,
          epochs=50, batch_size=256, callbacks=callbacks_list, shuffle=True)
# Out:
# Epoch 1/50
# 16/16 [==============================] - 71s 3s/step - loss: 7.7517 - accuracy: 0.4091 - val_loss: 5.8898 - val_accuracy: 0.5235
# Epoch 2/50
# 16/16 [==============================] - 50s 3s/step - loss: 5.7152 - accuracy: 0.5576 - val_loss: 5.0300 - val_accuracy: 0.5912
# Epoch 3/50
# 16/16 [==============================] - 42s 3s/step - loss: 4.7369 - accuracy: 0.6588 - val_loss: 4.5273 - val_accuracy: 0.6216
# Epoch 4/50
# 16/16 [==============================] - 50s 3s/step - loss: 4.0857 - accuracy: 0.7434 - val_loss: 4.1380 - val_accuracy: 0.6196
# Epoch 5/50
# 16/16 [==============================] - 63s 4s/step - loss: 3.5991 - accuracy: 0.7993 - val_loss: 3.7608 - val_accuracy: 0.6225
# Epoch 6/50
# 16/16 [==============================] - 53s 3s/step - loss: 3.1643 - accuracy: 0.8409 - val_loss: 3.4049 - val_accuracy: 0.6431
# Epoch 7/50
# 16/16 [==============================] - 38s 2s/step - loss: 2.8084 - accuracy: 0.8640 - val_loss: 3.1051 - val_accuracy: 0.6382
# Epoch 8/50
# 16/16 [==============================] - 45s 3s/step - loss: 2.4993 - accuracy: 0.8850 - val_loss: 2.8375 - val_accuracy: 0.6500
# Epoch 9/50
# 16/16 [==============================] - 48s 3s/step - loss: 2.2253 - accuracy: 0.9108 - val_loss: 2.6449 - val_accuracy: 0.6275
# Epoch 10/50
# 16/16 [==============================] - 62s 4s/step - loss: 1.9871 - accuracy: 0.9233 - val_loss: 2.4181 - val_accuracy: 0.6500
# Epoch 11/50
# 16/16 [==============================] - 42s 3s/step - loss: 1.7866 - accuracy: 0.9299 - val_loss: 2.2569 - val_accuracy: 0.6333
# Epoch 12/50
# 16/16 [==============================] - 50s 3s/step - loss: 1.6104 - accuracy: 0.9397 - val_loss: 2.0692 - val_accuracy: 0.6539
# Epoch 13/50
# 16/16 [==============================] - 40s 3s/step - loss: 1.4487 - accuracy: 0.9475 - val_loss: 1.9278 - val_accuracy: 0.6745
# Epoch 14/50
# 16/16 [==============================] - 50s 3s/step - loss: 1.3184 - accuracy: 0.9473 - val_loss: 1.8112 - val_accuracy: 0.6578
# Epoch 15/50
# 16/16 [==============================] - 52s 3s/step - loss: 1.1933 - accuracy: 0.9576 - val_loss: 1.7122 - val_accuracy: 0.6559
# Epoch 16/50
# 16/16 [==============================] - 51s 3s/step - loss: 1.0955 - accuracy: 0.9588 - val_loss: 1.6105 - val_accuracy: 0.6618
# Epoch 17/50
# 16/16 [==============================] - 48s 3s/step - loss: 1.0122 - accuracy: 0.9544 - val_loss: 1.5396 - val_accuracy: 0.6667
# Epoch 18/50
# 16/16 [==============================] - 47s 3s/step - loss: 0.9380 - accuracy: 0.9618 - val_loss: 1.4658 - val_accuracy: 0.6676
# Epoch 19/50
# 16/16 [==============================] - 36s 2s/step - loss: 0.8785 - accuracy: 0.9615 - val_loss: 1.4094 - val_accuracy: 0.6578
# Epoch 20/50
# 16/16 [==============================] - 51s 3s/step - loss: 0.8179 - accuracy: 0.9620 - val_loss: 1.3730 - val_accuracy: 0.6520
# Epoch 21/50
# 16/16 [==============================] - 47s 3s/step - loss: 0.7793 - accuracy: 0.9571 - val_loss: 1.3527 - val_accuracy: 0.6578
# Epoch 22/50
# 16/16 [==============================] - 48s 3s/step - loss: 0.7359 - accuracy: 0.9578 - val_loss: 1.2740 - val_accuracy: 0.6784
# Epoch 23/50
# 16/16 [==============================] - 28s 2s/step - loss: 0.7009 - accuracy: 0.9605 - val_loss: 1.2737 - val_accuracy: 0.6637
# Epoch 24/50
# 16/16 [==============================] - 38s 2s/step - loss: 0.6742 - accuracy: 0.9588 - val_loss: 1.2347 - val_accuracy: 0.6745
# Epoch 25/50
# 16/16 [==============================] - 36s 2s/step - loss: 0.6383 - accuracy: 0.9650 - val_loss: 1.2109 - val_accuracy: 0.6735
# Epoch 26/50
# 16/16 [==============================] - 33s 2s/step - loss: 0.6225 - accuracy: 0.9650 - val_loss: 1.2153 - val_accuracy: 0.6618
# Epoch 27/50
# 16/16 [==============================] - 33s 2s/step - loss: 0.6011 - accuracy: 0.9650 - val_loss: 1.1870 - val_accuracy: 0.6627
# Epoch 28/50
# 16/16 [==============================] - 36s 2s/step - loss: 0.5744 - accuracy: 0.9689 - val_loss: 1.1499 - val_accuracy: 0.6853
# Epoch 29/50
# 16/16 [==============================] - 37s 2s/step - loss: 0.5628 - accuracy: 0.9659 - val_loss: 1.1525 - val_accuracy: 0.6647
# Epoch 30/50
# 16/16 [==============================] - 31s 2s/step - loss: 0.5548 - accuracy: 0.9647 - val_loss: 1.1611 - val_accuracy: 0.6824
# Epoch 31/50
# 16/16 [==============================] - 25s 2s/step - loss: 0.5426 - accuracy: 0.9654 - val_loss: 1.1278 - val_accuracy: 0.6784
# Epoch 32/50
# 16/16 [==============================] - 22s 1s/step - loss: 0.5313 - accuracy: 0.9672 - val_loss: 1.1383 - val_accuracy: 0.6735
# Epoch 33/50
# 16/16 [==============================] - 31s 2s/step - loss: 0.5227 - accuracy: 0.9652 - val_loss: 1.1843 - val_accuracy: 0.6520
# Epoch 34/50
# 16/16 [==============================] - 32s 2s/step - loss: 0.5110 - accuracy: 0.9703 - val_loss: 1.0993 - val_accuracy: 0.6755
# Epoch 35/50
# 16/16 [==============================] - 34s 2s/step - loss: 0.4947 - accuracy: 0.9696 - val_loss: 1.1086 - val_accuracy: 0.6853
# Epoch 36/50
# 16/16 [==============================] - 33s 2s/step - loss: 0.4921 - accuracy: 0.9684 - val_loss: 1.1414 - val_accuracy: 0.6696
# Epoch 37/50
# 16/16 [==============================] - 34s 2s/step - loss: 0.4856 - accuracy: 0.9674 - val_loss: 1.0922 - val_accuracy: 0.6931
# Epoch 38/50
# 16/16 [==============================] - 22s 1s/step - loss: 0.4831 - accuracy: 0.9640 - val_loss: 1.0881 - val_accuracy: 0.6608
# Epoch 39/50
# 16/16 [==============================] - 20s 1s/step - loss: 0.4919 - accuracy: 0.9632 - val_loss: 1.1180 - val_accuracy: 0.6618
# Epoch 40/50
# 16/16 [==============================] - 15s 930ms/step - loss: 0.4838 - accuracy: 0.9640 - val_loss: 1.0894 - val_accuracy: 0.6755
# Epoch 41/50
# 16/16 [==============================] - 16s 1s/step - loss: 0.4891 - accuracy: 0.9593 - val_loss: 1.0920 - val_accuracy: 0.6892
# Epoch 42/50
# 16/16 [==============================] - 15s 972ms/step - loss: 0.4851 - accuracy: 0.9652 - val_loss: 1.1127 - val_accuracy: 0.6863
# Epoch 43/50
# 16/16 [==============================] - 14s 892ms/step - loss: 0.4678 - accuracy: 0.9730 - val_loss: 1.0792 - val_accuracy: 0.6784
# Epoch 44/50
# 16/16 [==============================] - 13s 805ms/step - loss: 0.4568 - accuracy: 0.9775 - val_loss: 1.0693 - val_accuracy: 0.6735
# Epoch 45/50
# 16/16 [==============================] - 13s 827ms/step - loss: 0.4511 - accuracy: 0.9701 - val_loss: 1.0804 - val_accuracy: 0.6951
# Epoch 46/50
# 16/16 [==============================] - 13s 812ms/step - loss: 0.4401 - accuracy: 0.9770 - val_loss: 1.0601 - val_accuracy: 0.6784
# Epoch 47/50
# 16/16 [==============================] - 13s 787ms/step - loss: 0.4313 - accuracy: 0.9750 - val_loss: 1.0589 - val_accuracy: 0.6863
# Epoch 48/50
# 16/16 [==============================] - 13s 794ms/step - loss: 0.4256 - accuracy: 0.9775 - val_loss: 1.0771 - val_accuracy: 0.6755
# Epoch 49/50
# 16/16 [==============================] - 13s 814ms/step - loss: 0.4384 - accuracy: 0.9725 - val_loss: 1.0784 - val_accuracy: 0.6863
# Epoch 50/50
# 16/16 [==============================] - 13s 793ms/step - loss: 0.4262 - accuracy: 0.9750 - val_loss: 1.0677 - val_accuracy: 0.6833

# %%
labels_test = data_test.iloc[:, 0].values
reviews_test = data_test.iloc[:, 1].values

# %%
encoded_labels_test = []

for label_test in labels_test:
    if label_test == -1:
        encoded_labels_test.append([1,0,0])
    elif label_test == 0:
        encoded_labels_test.append([0,1,0])
    else:
        encoded_labels_test.append([0,0,1])

encoded_labels_test = np.array(encoded_labels_test)

# %%
reviews_processed_test = []
unlabeled_processed_test = []
for review_test in reviews_test:
    # review_cool_one = ''.join([char for char in review_test if char not in digits])
    review_cool_one = ''.join([char for char in review_test])
    reviews_processed_test.append(review_cool_one)

# %%
#Use PyVi for Vietnamese word tokenizer
word_reviews_test = []
all_words = []
for review_test in reviews_processed_test:
    review_test = ViTokenizer.tokenize(review_test.lower())
    word_reviews_test.append(review_test.split())

# %%
sequences_test = tokenizer.texts_to_sequences(word_reviews_test)
data_test = pad_sequences(sequences_test, maxlen=MAX_SEQUENCE_LENGTH)
labels_test = encoded_labels_test

# %%
print('Shape of X train and X validation tensor:',data_test.shape)
print('Shape of label train and validation tensor:', labels_test.shape)
# Out:
# Shape of X train and X validation tensor: (1050, 300)
# Shape of label train and validation tensor: (1050, 3)

# %%
# model = load_model('best_model.keras')
score = model.evaluate(data_test, labels_test)
# Out:
# 33/33 [==============================] - 1s 25ms/step - loss: 1.0389 - accuracy: 0.6952

# %%
print("%s: %.2f%%" % (model.metrics_names[0], score[0]*100))
print("%s: %.2f%%" % (model.metrics_names[1], score[1]*100))
# Out:
# loss: 103.89%
# accuracy: 69.52%
